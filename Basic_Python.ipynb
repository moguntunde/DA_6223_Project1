# %% [markdown]
# <a href="https://colab.research.google.com/github/moguntunde/DA_6223_Project1/blob/main/Basic_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+2
# Out:
# 4

# %%
2<4
# Out:
# True

# %%
print("Hello World")
# Out:
# Hello World

# %%
students_counts = 1000

# %%
rating =4.99

# %%
is_published = True

# %%
print(students_counts)
# Out:
# 1000

# %%
course_name ="Python Programming"

# %%
print(course_name)
# Out:
# Python
#  Programming

# %%
first ="Mart"
Last ="Ogun"

# %%
full = f"{first} {Last}"

# %%
print(course_name.upper())
# Out:
# PYTHON PROGRAMMING

# %%
print(course_name)
# Out:
# Python Programming

# %%
print(course_name.strip())
# Out:
# Python Programming

# %%
print("NAN" not in course_name)
# Out:
# True

# %% [markdown]
# # In pythons we have three numbers; intergers and float
# #x = 1 interger
# #x = 1 float
# **bold text**

# %%
print(10%3)
# Out:
# 1

# %%
print(abs(-2.9))
# Out:
# 2.9

# %%
x =input("x: ")
y = int(x) + 1
# Out:
# x: 2

# %%
print(f"x: {x}, y: {y}")
# Out:
# x: 2, y: 3

# %%
fruit = "Apple"
print([1])
# Out:
# [1]

# %%
print(bool("False"))
# Out:
# True

# %%
temperature = 25

# %%
if temperature > 30:
  print("It's a hot day")
  print("Drink plenty of water")
elif temperature > 20:
  print("It's a nice day")
else:
  print("It's cold")
print("Done")
# Out:
# It's a nice day
# Done

# %%
age =12

# %% [markdown]
# Conditional Statements

# %%
if age >= 18:
  message="Eligible"
else:
  message = "Not Eligbile"
print(message)
# Out:
# Not Eligbile

# %%
message = "Eligible" if age >= 18 else "Not Eligible"
print(message)
# Out:
# Not Eligible

# %%
high_income = True
good_credit = False
student = False
if high_income and good_credit:
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Not Eligible

# %%
if not student:
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Eligible

# %%
if high_income and good_credit and not student:
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Not Eligible

# %% [markdown]
# Change comparison operator

# %%
age = 22
if 18 <= age < 65:
  print("Eligible")
# Out:
# Eligible

# %% [markdown]
# **Loop:Used to create a repetetive statement**

# %%
for number in range(1,3):
  print("Attempt", number + 1, (number +1)*".")
# Out:
# Attempt 2 ..
# Attempt 3 ...

# %%
successful = True
for number in range(3):
  print("Attempt")
  if successful:
    print("Successful")
    break
else:
  print("Attemped 3 times and failed")
# Out:
# Attempt
# Successful

# %% [markdown]
# Nested Loop

# %%
for x in range(5):
  for y in range(3):
    print(f"({x}, {y})")
# Out:
# (0, 0)
# (0, 1)
# (0, 2)
# (1, 0)
# (1, 1)
# (1, 2)
# (2, 0)
# (2, 1)
# (2, 2)
# (3, 0)
# (3, 1)
# (3, 2)
# (4, 0)
# (4, 1)
# (4, 2)

# %%
print(type(5))
# Out:
# <class 'int'>

# %%
print(type(range(5)))
# Out:
# <class 'range'>

# %%
for x in "python":
  print(x)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for x in [1,2,3,4]:
  print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
number = 100
while number > 0:
  print(number)
  number //= 2
# Out:
# 100
# 50
# 25
# 12
# 6
# 3
# 1

# %%
command = ""
while command.lower() != "quit":
  command = input(">")
  print("ECHO", command)
# Out:
# >2+2
# ECHO 2+2
# >3+3
# ECHO 3+3
# >quit
# ECHO quit

# %%
MTG = 48
Kemp =49.9

if MTG > 50:
  print("congratulations to MTG")
else:
  print("congratulations to Kemp")
# Out:
# congratulations to Kemp

# %%
count = 0
for number in range(1,10):
  if number % 2 == 0:
    count += 1
    print(number)
print (f"We have", count, "even numbers")
# Out:
# 2
# 4
# 6
# 8
# We have 4 even numbers

# %%
def greet(first_name, last_name):
  print(f"Hi {first_name} {last_name}")
  print("Welcome aboard")

greet("Mart","Oguntunde")
greet("Mart","Oguntunde")
# Out:
# Hi Mart Oguntunde
# Welcome aboard
# Hi Mart Oguntunde
# Welcome aboard

# %%
def get_greeting(name):
  return f"Hi {name}"

message = get_greeting("Mart")
print(message)
# Out:
# Hi Mart

# %%
def increment( number,by):
  return number + by


result = increment(2,1)
print(result)
# Out:
# 3

# %%
def increment( number,by):
  return number + by



print(increment(2, by=1))
# Out:
# 3

# %%
def multiply(*number):
  print(number)


multiply(2,3,4)
# Out:
# (2, 3, 4)

# %%
def multiply(*number):
  total = 1
  for num in number:
    total *= num
  return total


print(multiply(2,3,4))
# Out:
# 24

# %% [markdown]
# Full Course

# %%
#Variables are used to temporarily used to store data

price = 10

# %%
print(price)
# Out:
# 10

# %%
name = "John Smith"
Age = 20
is_a_newpatient = True

# %%
name = input('what is your name?')
favorite_color = input('what is your favorite color?')
print(name + ' likes ' + favorite_color)
print('Hi ' + name)
# Out:
# what is your name?Martin
# what is your favorite color?Blue
# Martin likes Blue
# Hi Martin

# %%
birth_year = input('Birth year: ')
age = 2026 - int(birth_year)
print(age)
# Out:
# Birth year: 1980
# 46

# %%
weight_lbs = input('weight (lbs): ')
weight_kg = int(weight_lbs)*0.45
print(weight_kg)
# Out:
# weight (lbs): 160
# 72.0

# %%
course = 'Python for Beginners'
print(course[0])
print(course[-1])
print(course[0:3])
# Out:
# P
# s
# Pyt

# %%
status ="""
Hi John
what is going on
there"""
print(status)
# Out:
# Hi John
# what is going on
# there

# %%
first = 'John'
last ='Smith'
message = first + ' [' + last + '] is a coder'
msg =  f'{first} {last} is a coder'
print(message)
print(msg)
# Out:
# John [Smith] is a coder
# John Smith is a coder

# %%
print(course.upper())
# Out:
# PYTHON FOR BEGINNERS

# %%
adj= course.replace('for', '4')
print(adj)
# Out:
# Python 4 Beginners

# %%
print( 10 % 3)
# Out:
# 1

# %%
x = 10
x-=3
print(x)
# Out:
# 7

# %%
#Absolute always return a positive number back

x= 2.9
print(round(x))
print(abs(-2.9))
# Out:
# 3
# 2.9

# %%
import math

# %%
print(math.ceil(2.9))
# Out:
# 3

# %%
#If statement


is_hot = False
is_cold = False


if is_hot:
  print("It's a hot day!")
  print('enjoy your day')
  print("Drink plenty of water")
elif is_cold:
  print("It's a cold day")
  print("Wear warm clothes")
else:
  print("It's a lovely ,")
print("Enjoy your day")
# Out:
# It's a lovely ,
# Enjoy your day

# %%
price = 1000000
has_good_credit = True

if has_good_credit:
  down_payment = 0.1*price
else:
    down_payment = 0.2*price
print(f"Down payment: ${down_payment}")
# Out:
# Down payment: $100000.0

# %%
high_income = True
criminal_record = False

if high_income and criminal_record:
  print("Eligible for loan")

# %%
temperature = 30

if temperature != 30:
  print('it is a hot day')
else:
  print('It is not a hot day')
# Out:
# It is not a hot day

# %%
name = "Jill"



if len(name) < 3:
  print("Name must be at least 3 characters")
elif len(name) > 50:
  print("Name must be maximum of 50 characters")
else:
    print("Name looks good")
# Out:
# Name looks good

# %%
weight = input('weight: ')
unit = input('(L)bs or (K)g: ')


if unit.upper == "L":
  converted = int(weight) * 0.45
  print(f"You are {converted} kilos")
else:
  converted = int(weight) / 0.45
  print(f"You are {converted} pounds")
# Out:
# weight: 203
# (L)bs or (K)g: l
# You are 451.1111111111111 pounds

# %%
i = 1
while i <= 5:
  print('*'* i)
  i = i*3
print("Done")
# Out:
# *
# ***
# Done

# %%
secret_number = 9
guess_count = 0
guess_limit = 3

while guess_count < guess_limit:
  guess = int(input('Guess: '))
  guess_count += 1
  if guess == secret_number:
    print("You won!")
    break
else:
  print("Sorry, you failed")
# Out:
# Guess: 9
# You won!

# %%
command = ""
started = False

while True:
  command = input(">").lower()

  if command == "start":
    if started:
      print("Car is already started!")
    else:
      started = True
      print("Car started... Ready to go!")
  elif command == "stop":
    if not started:
      print("Car is already stopped.")
    else:
      started = False
      print("Car stopped.")
  elif command == "help":
    print("""
start - to start the car
stop - to stop the car
quit - to quit
""")
  elif command == "quit":
    break
  else:
    print("Sorry I don't understand that command!")
# Out:
# >start
# Car started... Ready to go!
# >start
# Car is already started!
# >stop
# Car stopped.
# >stop
# Car is already stopped.
# >quit
