# %% [markdown]
# <a href="https://colab.research.google.com/github/moguntunde/DA_6223_Project1/blob/main/Copy_of_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+2
# Out:
# 4

# %%
2<4
# Out:
# True

# %%
print("Hello World")
# Out:
# Hello World

# %%
students_counts = 1000

# %%
rating =4.99

# %%
is_published = True

# %%
print(students_counts)
# Out:
# 1000

# %%
course_name ="Python Programming"

# %%
print(course_name)
# Out:
# Python
#  Programming

# %%
first ="Mart"
Last ="Ogun"

# %%
full = f"{first} {Last}"

# %%
print(course_name.upper())
# Out:
# PYTHON PROGRAMMING

# %%
print(course_name)
# Out:
# Python Programming

# %%
print(course_name.strip())
# Out:
# Python Programming

# %%
print("NAN" not in course_name)
# Out:
# True

# %% [markdown]
# # In pythons we have three numbers; intergers and float
# #x = 1 interger
# #x = 1 float
# **bold text**

# %%
print(10%3)
# Out:
# 1

# %%
print(abs(-2.9))
# Out:
# 2.9

# %%
x =input("x: ")
y = int(x) + 1
# Out:
# x: 2

# %%
print(f"x: {x}, y: {y}")
# Out:
# x: 2, y: 3

# %%
fruit = "Apple"
print([1])
# Out:
# [1]

# %%
print(bool("False"))
# Out:
# True

# %%
temperature = 25

# %%
if temperature > 30:
  print("It's a hot day")
  print("Drink plenty of water")
elif temperature > 20:
  print("It's a nice day")
else:
  print("It's cold")
print("Done")
# Out:
# It's a nice day
# Done

# %%
age =12

# %% [markdown]
# Conditional Statements

# %%
if age >= 18:
  message="Eligible"
else:
  message = "Not Eligbile"
print(message)
# Out:
# Not Eligbile

# %%
message = "Eligible" if age >= 18 else "Not Eligible"
print(message)
# Out:
# Not Eligible

# %%
high_income = True
good_credit = False
student = False
if high_income and good_credit:
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Not Eligible

# %%
if not student:
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Eligible

# %%
if high_income and good_credit and not student:
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Not Eligible

# %% [markdown]
# Change comparison operator

# %%
age = 22
if 18 <= age < 65:
  print("Eligible")
# Out:
# Eligible

# %% [markdown]
# **Loop:Used to create a repetetive statement**

# %%
for number in range(1,3):
  print("Attempt", number + 1, (number +1)*".")
# Out:
# Attempt 2 ..
# Attempt 3 ...

# %%
successful = True
for number in range(3):
  print("Attempt")
  if successful:
    print("Successful")
    break
else:
  print("Attemped 3 times and failed")
# Out:
# Attempt
# Successful

# %% [markdown]
# Nested Loop

# %%
for x in range(5):
  for y in range(3):
    print(f"({x}, {y})")
# Out:
# (0, 0)
# (0, 1)
# (0, 2)
# (1, 0)
# (1, 1)
# (1, 2)
# (2, 0)
# (2, 1)
# (2, 2)
# (3, 0)
# (3, 1)
# (3, 2)
# (4, 0)
# (4, 1)
# (4, 2)

# %%
print(type(5))
# Out:
# <class 'int'>

# %%
print(type(range(5)))
# Out:
# <class 'range'>

# %%
for x in "python":
  print(x)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for x in [1,2,3,4]:
  print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
number = 100
while number > 0:
  print(number)
  number //= 2
# Out:
# 100
# 50
# 25
# 12
# 6
# 3
# 1

# %%
command = ""
while command.lower() != "quit":
  command = input(">")
  print("ECHO", command)
# Out:
# >2+2
# ECHO 2+2
# >3+3
# ECHO 3+3
# >quit
# ECHO quit

# %%
MTG = 48
Kemp =49.9

if MTG > 50:
  print("congratulations to MTG")
else:
  print("congratulations to Kemp")
# Out:
# congratulations to Kemp

# %%
count = 0
for number in range(1,10):
  if number % 2 == 0:
    count += 1
    print(number)
print (f"We have", count, "even numbers")
# Out:
# 2
# 4
# 6
# 8
# We have 4 even numbers

# %%
def greet(first_name, last_name):
  print(f"Hi {first_name} {last_name}")
  print("Welcome aboard")

greet("Mart","Oguntunde")
greet("Mart","Oguntunde")
# Out:
# Hi Mart Oguntunde
# Welcome aboard
# Hi Mart Oguntunde
# Welcome aboard

# %%
def get_greeting(name):
  return f"Hi {name}"

message = get_greeting("Mart")
print(message)
# Out:
# Hi Mart

# %%
def increment( number,by):
  return number + by


result = increment(2,1)
print(result)
# Out:
# 3

# %%
def increment( number,by):
  return number + by



print(increment(2, by=1))
# Out:
# 3

# %%
def multiply(*number):
  print(number)


multiply(2,3,4)
# Out:
# (2, 3, 4)

# %%
def multiply(*number):
  total = 1
  for num in number:
    total *= num
  return total


print(multiply(2,3,4))
# Out:
# 24
